# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("data/k1_i0_d1_m0.02_ep0.1.csv", delimiter=',', dtype=str)

# %%
data = data[:, :-1].astype(int).transpose()
print(data.shape)
# Out:
# (7999, 501)

# %%
data = data[np.where(np.sum(data, 1) != 0)]
print(data.shape)
# Out:
# (20, 501)

# %%
fig, ax = plt.subplots(figsize=(10,7))
for d in range(data.shape[0]):
    ax.plot(range(data.shape[1]), data[d, :])
plt.show()

# %%
def process_and_plot(params, ax):
    name = "data/k{}_i{}_d{}_m{}_ep{}.csv".format(
            params['k'],
            params['i'],
            params['d'],
            params['m'],
            params['ep'])
    data = np.loadtxt(name, delimiter=',', dtype=str)
    data = data[:, :-1].astype(int).transpose()
    data = data[np.where(np.sum(data, 1) != 0)]
#     fig, ax = plt.subplots(figsize=(10,7))
    for d in range(data.shape[0]):
        ax.plot(range(data.shape[1]), data[d, :])

def process_param(param_n):

# %%
fig, ax = plt.subplots(figsize=(10,7))
process_and_plot({"k":1, "i":0, "d":1, "m":0.08, "ep":0.1}, ax)

# %%
process_and_plot("data/k2_i2_d1_m0.08_ep0.1.csv")

# %%
process_and_plot("data/k3_i0_d1_m0.08_ep0.1.csv")
